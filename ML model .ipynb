# %%
# Mohit  - 07/07/21

# %%
#importing all the libraries needed
import pandas as pd
import numpy as np
from IPython.display import FileLink, FileLinks

# %%
import seaborn as sns
import sklearn

# %% [markdown]
# ## Reading the data

# %%
df=pd.read_csv("H2HBABBA3245.csv")

# %%
df.head(10)
# Out:
#   business_code cust_number       name_customer           clear_date  \
# 0          CA02  0140104249              SOB in  2020-01-27 00:00:00
# 1          U001   200769623  WAL-MAR foundation                  NaN
# 2          U001  0200936373           SUPE corp  2019-05-29 00:00:00
# 3          U001  0200769623          WAL-MAR us  2019-07-29 00:00:00
# 4          U001   200777735           NASH  llc  2019-06-18 00:00:00
# 5          U001  0200769623            WAL-MAR   2019-10-21 00:00:00
# 6          U001  0200769623        WAL-MAR corp  2019-12-03 00:00:00
# 7          U001  0100036292              AMY co                  NaN
# 8          U001      CCCA02           KRAFT  in  2020-02-28 00:00:00
# 9          U001  0200803720     DEC corporation  2019-04-26 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2020.0  2.960605e+09   2020-01-04              20200104
# 1         2020.0  1.930766e+09   2020-04-09              20200408
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   buisness_year           50000 non-null  float64
#  5   doc_id                  50000 non-null  float64
#  6   posting_date            50000 non-null  object
#  7   document_create_date    50000 non-null  int64
#  8   document_create_date.1  50000 non-null  int64
#  9   due_in_date             50000 non-null  float64
#  10  invoice_currency        50000 non-null  object
#  11  document type           50000 non-null  object
#  12  posting_id              50000 non-null  float64
#  13  area_business           0 non-null      float64
# ...

# %%
df.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                 object
# buisness_year             float64
# doc_id                    float64
# posting_date               object
# document_create_date        int64
# document_create_date.1      int64
# due_in_date               float64
# invoice_currency           object
# document type              object
# posting_id                float64
# area_business             float64
# total_open_amount         float64
# baseline_create_date      float64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
# checking for nulll values
df.isna().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             50000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    6
# isOpen                        0
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# business_code               0.000
# cust_number                 0.000
# name_customer               0.000
# clear_date                 20.000
# buisness_year               0.000
# doc_id                      0.000
# posting_date                0.000
# document_create_date        0.000
# document_create_date.1      0.000
# due_in_date                 0.000
# invoice_currency            0.000
# document type               0.000
# posting_id                  0.000
# area_business             100.000
# total_open_amount           0.000
# baseline_create_date        0.000
# cust_payment_terms          0.000
# invoice_id                  0.012
# isOpen                      0.000
# dtype: float64

# %%
df.shape
# Out:
# (50000, 19)

# %%
# we split dataset into train and global test
# all null values in clear_date will be taken to global_test dataset

# %%
global_test=df[df['clear_date'].isnull()]

# %%
global_test
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 1              U001   200769623  WAL-MAR foundation        NaN         2020.0
# 7              U001  0100036292              AMY co        NaN         2020.0
# 10             U001  0200778870        C associates        NaN         2020.0
# 11             U001  0200704858        WAKE systems        NaN         2020.0
# 15             U001  0200762301         C&S WH corp        NaN         2020.0
# ...             ...         ...                 ...        ...            ...
# 49967          U001  0200707741    SMART &  systems        NaN         2020.0
# 49978          U001  0200799342            MITCH in        NaN         2020.0
# 49979          U001  0200762301             C&S WH         NaN         2020.0
# 49981          U001   200726979         BJ'S  trust        NaN         2020.0
# 49994          U001   200418007      AM corporation        NaN         2020.0
#
# ...

# %%
test=global_test.copy()
#drop form main dataframe 
df.dropna(subset=["clear_date"],axis=0,inplace=True)

# %%
test
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 1              U001   200769623  WAL-MAR foundation        NaN         2020.0
# 7              U001  0100036292              AMY co        NaN         2020.0
# 10             U001  0200778870        C associates        NaN         2020.0
# 11             U001  0200704858        WAKE systems        NaN         2020.0
# 15             U001  0200762301         C&S WH corp        NaN         2020.0
# ...             ...         ...                 ...        ...            ...
# 49967          U001  0200707741    SMART &  systems        NaN         2020.0
# 49978          U001  0200799342            MITCH in        NaN         2020.0
# 49979          U001  0200762301             C&S WH         NaN         2020.0
# 49981          U001   200726979         BJ'S  trust        NaN         2020.0
# 49994          U001   200418007      AM corporation        NaN         2020.0
#
# ...

# %%
test.to_csv(r'Downloads\global_testfinal.csv', index = True)

# %% [markdown]
# ## Preprocessing

# %%
# checking for null values and remove them 
df.isna().sum()/len(df)*100
# Out:
# business_code               0.000
# cust_number                 0.000
# name_customer               0.000
# clear_date                  0.000
# buisness_year               0.000
# doc_id                      0.000
# posting_date                0.000
# document_create_date        0.000
# document_create_date.1      0.000
# due_in_date                 0.000
# invoice_currency            0.000
# document type               0.000
# posting_id                  0.000
# area_business             100.000
# total_open_amount           0.000
# baseline_create_date        0.000
# cust_payment_terms          0.000
# invoice_id                  0.015
# isOpen                      0.000
# dtype: float64

# %%
df.drop('area_business',axis=1,inplace=True)

# %%
df
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              CA02  0140104249              SOB in  2020-01-27 00:00:00
# 2              U001  0200936373           SUPE corp  2019-05-29 00:00:00
# 3              U001  0200769623          WAL-MAR us  2019-07-29 00:00:00
# 4              U001   200777735           NASH  llc  2019-06-18 00:00:00
# 5              U001  0200769623            WAL-MAR   2019-10-21 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200769623  WAL-MAR associates  2019-01-11 00:00:00
# 49996          U001  0200759878       SA associates  2019-02-12 00:00:00
# 49997          U001      CCCA02   KRAFT  foundation  2020-03-27 00:00:00
# 49998          U001  0200418007              AM llc  2019-10-02 00:00:00
# 49999          U001  0200750051            ALBER co  2019-08-28 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
df.nunique()
# Out:
# business_code                 6
# cust_number                1349
# name_customer              3915
# clear_date                  403
# buisness_year                 2
# doc_id                    39098
# posting_date                422
# document_create_date        424
# document_create_date.1      422
# due_in_date                 490
# invoice_currency              2
# document type                 2
# posting_id                    1
# total_open_amount         35550
# baseline_create_date        430
# cust_payment_terms           74
# invoice_id                39092
# isOpen                        1
# dtype: int64

# %%
# checking for duplicated rows and remove them
df.duplicated()
# Out:
# 0        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Length: 40000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 902

# %%
df.drop_duplicates(keep="first",inplace=True)
df
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              CA02  0140104249              SOB in  2020-01-27 00:00:00
# 2              U001  0200936373           SUPE corp  2019-05-29 00:00:00
# 3              U001  0200769623          WAL-MAR us  2019-07-29 00:00:00
# 4              U001   200777735           NASH  llc  2019-06-18 00:00:00
# 5              U001  0200769623            WAL-MAR   2019-10-21 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200769623  WAL-MAR associates  2019-01-11 00:00:00
# 49996          U001  0200759878       SA associates  2019-02-12 00:00:00
# 49997          U001      CCCA02   KRAFT  foundation  2020-03-27 00:00:00
# 49998          U001  0200418007              AM llc  2019-10-02 00:00:00
# 49999          U001  0200750051            ALBER co  2019-08-28 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
# Check constant columns and remove beccause that doesnt help model train 
unique=[x for x in df.columns if df[x].nunique()==1]
unique
# Out:
# ['posting_id', 'isOpen']

# %%
df.nunique()
# Out:
# business_code                 6
# cust_number                1349
# name_customer              3915
# clear_date                  403
# buisness_year                 2
# doc_id                    39098
# posting_date                422
# document_create_date        424
# document_create_date.1      422
# due_in_date                 490
# invoice_currency              2
# document type                 2
# posting_id                    1
# total_open_amount         35550
# baseline_create_date        430
# cust_payment_terms           74
# invoice_id                39092
# isOpen                        1
# dtype: int64

# %%
df.drop('posting_id',axis=1,inplace=True)

# %%
df
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              CA02  0140104249              SOB in  2020-01-27 00:00:00
# 2              U001  0200936373           SUPE corp  2019-05-29 00:00:00
# 3              U001  0200769623          WAL-MAR us  2019-07-29 00:00:00
# 4              U001   200777735           NASH  llc  2019-06-18 00:00:00
# 5              U001  0200769623            WAL-MAR   2019-10-21 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200769623  WAL-MAR associates  2019-01-11 00:00:00
# 49996          U001  0200759878       SA associates  2019-02-12 00:00:00
# 49997          U001      CCCA02   KRAFT  foundation  2020-03-27 00:00:00
# 49998          U001  0200418007              AM llc  2019-10-02 00:00:00
# 49999          U001  0200750051            ALBER co  2019-08-28 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
df.drop('isOpen',axis=1,inplace=True)

# %%
df
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              CA02  0140104249              SOB in  2020-01-27 00:00:00
# 2              U001  0200936373           SUPE corp  2019-05-29 00:00:00
# 3              U001  0200769623          WAL-MAR us  2019-07-29 00:00:00
# 4              U001   200777735           NASH  llc  2019-06-18 00:00:00
# 5              U001  0200769623            WAL-MAR   2019-10-21 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200769623  WAL-MAR associates  2019-01-11 00:00:00
# 49996          U001  0200759878       SA associates  2019-02-12 00:00:00
# 49997          U001      CCCA02   KRAFT  foundation  2020-03-27 00:00:00
# 49998          U001  0200418007              AM llc  2019-10-02 00:00:00
# 49999          U001  0200750051            ALBER co  2019-08-28 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
df.isna().sum()
# Out:
# business_code             0
# cust_number               0
# name_customer             0
# clear_date                0
# buisness_year             0
# doc_id                    0
# posting_date              0
# document_create_date      0
# document_create_date.1    0
# due_in_date               0
# invoice_currency          0
# document type             0
# total_open_amount         0
# baseline_create_date      0
# cust_payment_terms        0
# invoice_id                6
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# business_code             0.000000
# cust_number               0.000000
# name_customer             0.000000
# clear_date                0.000000
# buisness_year             0.000000
# doc_id                    0.000000
# posting_date              0.000000
# document_create_date      0.000000
# document_create_date.1    0.000000
# due_in_date               0.000000
# invoice_currency          0.000000
# document type             0.000000
# total_open_amount         0.000000
# baseline_create_date      0.000000
# cust_payment_terms        0.000000
# invoice_id                0.015346
# dtype: float64

# %%
#only 0.02% of values are null for invoice id column . so we can fill those with mean values
df['invoice_id'].fillna(df['invoice_id'].mean(),inplace=True)

# %%
df
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              CA02  0140104249              SOB in  2020-01-27 00:00:00
# 2              U001  0200936373           SUPE corp  2019-05-29 00:00:00
# 3              U001  0200769623          WAL-MAR us  2019-07-29 00:00:00
# 4              U001   200777735           NASH  llc  2019-06-18 00:00:00
# 5              U001  0200769623            WAL-MAR   2019-10-21 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200769623  WAL-MAR associates  2019-01-11 00:00:00
# 49996          U001  0200759878       SA associates  2019-02-12 00:00:00
# 49997          U001      CCCA02   KRAFT  foundation  2020-03-27 00:00:00
# 49998          U001  0200418007              AM llc  2019-10-02 00:00:00
# 49999          U001  0200750051            ALBER co  2019-08-28 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
# finally no null values ;
df.isna().sum()
# Out:
# business_code             0
# cust_number               0
# name_customer             0
# clear_date                0
# buisness_year             0
# doc_id                    0
# posting_date              0
# document_create_date      0
# document_create_date.1    0
# due_in_date               0
# invoice_currency          0
# document type             0
# total_open_amount         0
# baseline_create_date      0
# cust_payment_terms        0
# invoice_id                0
# dtype: int64

# %%
# no duplicate rows as well 
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                 object
# buisness_year             float64
# doc_id                    float64
# posting_date               object
# document_create_date        int64
# document_create_date.1      int64
# due_in_date               float64
# invoice_currency           object
# document type              object
# total_open_amount         float64
# baseline_create_date      float64
# cust_payment_terms         object
# invoice_id                float64
# dtype: object

# %%
df.nunique()
# Out:
# business_code                 6
# cust_number                1349
# name_customer              3915
# clear_date                  403
# buisness_year                 2
# doc_id                    39098
# posting_date                422
# document_create_date        424
# document_create_date.1      422
# due_in_date                 490
# invoice_currency              2
# document type                 2
# total_open_amount         35550
# baseline_create_date        430
# cust_payment_terms           74
# invoice_id                39093
# dtype: int64

# %%
df.cov()
# Out:
#                         buisness_year        doc_id  document_create_date  \
# buisness_year            1.157260e-01 -1.166136e+06          1.057224e+03
# doc_id                  -1.166136e+06  8.642594e+16         -8.079400e+09
# document_create_date     1.057224e+03 -8.079400e+09          1.064378e+07
# document_create_date.1   1.067667e+03 -1.076579e+10          1.045539e+07
# due_in_date              1.095811e+03 -1.282465e+10          1.015717e+07
# total_open_amount       -1.146354e+02  2.012637e+12         -6.667890e+05
# baseline_create_date     1.070005e+03 -6.919290e+09          1.044769e+07
# invoice_id              -1.012672e+06  7.782440e+16         -6.391839e+09
#
#                         document_create_date.1   due_in_date  \
# buisness_year                     1.067667e+03  1.095811e+03
# doc_id                           -1.076579e+10 -1.282465e+10
# document_create_date              1.045539e+07  1.015717e+07
# ...

# %%
# lets see the value counts of each column to get an idea of its distribution
for col in df.columns:
    if df[col].nunique()<= 500:
        print(df[col].value_counts())
        print('                      ')
# Out:
# U001    35280
# CA02     3121
# U013      551
# U002      131
# U005       12
# U007        3
# Name: business_code, dtype: int64
#
# 2019-09-03 00:00:00    280
# 2019-05-31 00:00:00    265
# 2019-11-12 00:00:00    254
# 2019-12-02 00:00:00    240
# 2019-03-29 00:00:00    237
#                       ...
# 2019-01-07 00:00:00      1
# 2019-01-02 00:00:00      1
# 2019-12-21 00:00:00      1
# 2019-07-20 00:00:00      1
# 2019-07-06 00:00:00      1
# Name: clear_date, Length: 403, dtype: int64
#
# 2019.0    33876
# 2020.0     5222
# Name: buisness_year, dtype: int64
#
# 2019-09-10    163
# 2019-06-25    157
# 2019-03-20    157
# 2019-05-08    152
# 2019-05-15    150
#              ...
# 2019-12-24     11
# 2019-12-27      7
# 2019-12-26      7
# 2020-02-27      5
# 2019-12-28      2
# Name: posting_date, Length: 422, dtype: int64
#
# 20190910    175
# 20190625    162
# 20190403    154
# 20190508    154
# 20190521    153
#            ...
# 20191226      7
# 20200227      7
# ...

# %%
# Converting datatypes ( datetime coversion)
df['clear_date']=pd.to_datetime(df['clear_date'])

# %%
df['baseline_create_date']=pd.to_datetime(df['baseline_create_date'],format='%Y%m%d')

# %%
df['document_create_date']=pd.to_datetime(df['document_create_date'],format='%Y%m%d')

# %%
df['document_create_date.1']=pd.to_datetime(df['document_create_date.1'],format='%Y%m%d')

# %%
df['posting_date']=pd.to_datetime(df['posting_date'])

# %%
df.dtypes
# Out:
# business_code                     object
# cust_number                       object
# name_customer                     object
# clear_date                datetime64[ns]
# buisness_year                    float64
# doc_id                           float64
# posting_date              datetime64[ns]
# document_create_date      datetime64[ns]
# document_create_date.1    datetime64[ns]
# due_in_date                      float64
# invoice_currency                  object
# document type                     object
# total_open_amount                float64
# baseline_create_date      datetime64[ns]
# cust_payment_terms                object
# invoice_id                       float64
# dtype: object

# %%
df['posting_date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
#Sorting our dataframe with baseline create date
df = df.sort_values(by="baseline_create_date")

# %%
df
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 39428          U001  0200455322      PEA foundation 2019-02-19         2019.0
# 19975          U001  0200519201    KROGE foundation 2019-01-14         2019.0
# 41334          U001  0200769623     WAL-MAR systems 2019-01-09         2019.0
# 18739          U001  0200769623  WAL-MAR associates 2019-01-09         2019.0
# 6124           U001  0200726979          BJ'S  corp 2019-01-15         2019.0
# ...             ...         ...                 ...        ...            ...
# 34093          CA02  0140105847    GORDON F systems 2020-03-16         2020.0
# 48621          CA02  0140105686            SYSC llc 2020-03-19         2020.0
# 22219          CA02  0140104409             LOB llc 2020-03-16         2020.0
# 48326          CA02  0140106293           ATLANT co 2020-03-16         2020.0
# 45324          U001  0200424504               M  us 2020-03-16         2020.0
#
# ...

# %%
# checking if clear_date column year is same as buisness_year column
df['buisness_year'].dtypes
# Out:
# dtype('float64')

# %%
df['buisness_year']=df['buisness_year'].astype(np.int64)

# %%
df['b']=df['clear_date'].dt.year

# %%
df['b'].dtypes
# Out:
# dtype('int64')

# %%
df['b'].corr(df['buisness_year'])*100
# Out:
# 100.0

# %%
# we see that it correlates 100% so clear_date column year is the same as column buisness year

# %%
df['buisness_year']=df['b']
df
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 39428          U001  0200455322      PEA foundation 2019-02-19           2019
# 19975          U001  0200519201    KROGE foundation 2019-01-14           2019
# 41334          U001  0200769623     WAL-MAR systems 2019-01-09           2019
# 18739          U001  0200769623  WAL-MAR associates 2019-01-09           2019
# 6124           U001  0200726979          BJ'S  corp 2019-01-15           2019
# ...             ...         ...                 ...        ...            ...
# 34093          CA02  0140105847    GORDON F systems 2020-03-16           2020
# 48621          CA02  0140105686            SYSC llc 2020-03-19           2020
# 22219          CA02  0140104409             LOB llc 2020-03-16           2020
# 48326          CA02  0140106293           ATLANT co 2020-03-16           2020
# 45324          U001  0200424504               M  us 2020-03-16           2020
#
# ...

# %%
df.drop(['b'],axis=1,inplace=True)

# %%
# Lets add  atarget colum as delay which is difference ofclear_date and due-in_date

# %%
df['due_in_date']=pd.to_datetime(df['due_in_date'],format='%Y%m%d')

# %%
#converting all dates into days of same datatype int . so its easy top perform operations on datetime datatypes

# %%
df.dtypes
# Out:
# business_code                     object
# cust_number                       object
# name_customer                     object
# clear_date                datetime64[ns]
# buisness_year                      int64
# doc_id                           float64
# posting_date              datetime64[ns]
# document_create_date      datetime64[ns]
# document_create_date.1    datetime64[ns]
# due_in_date               datetime64[ns]
# invoice_currency                  object
# document type                     object
# total_open_amount                float64
# baseline_create_date      datetime64[ns]
# cust_payment_terms                object
# invoice_id                       float64
# dtype: object

# %%
# converting dates into days by subtracting from 1970-01-01 which is computer date so we will have all days in int datatype
df['clear_date'] = df['clear_date'].sub(pd.to_datetime('1970-01-01'), axis=0)

# %%
df['clear_date']=df['clear_date'].dt.days

# %%
df['due_in_date'] = df['due_in_date'].sub(pd.to_datetime('1970-01-01'), axis=0)

# %%
df['due_in_date']=df['due_in_date'].dt.days

# %%
#creating target column delay 
df['delay'] = df['clear_date'].sub(df['due_in_date'], axis=0)

# %%
df.dtypes
# Out:
# business_code                     object
# cust_number                       object
# name_customer                     object
# clear_date                         int64
# buisness_year                      int64
# doc_id                           float64
# posting_date              datetime64[ns]
# document_create_date      datetime64[ns]
# document_create_date.1    datetime64[ns]
# due_in_date                        int64
# invoice_currency                  object
# document type                     object
# total_open_amount                float64
# baseline_create_date      datetime64[ns]
# cust_payment_terms                object
# invoice_id                       float64
# delay                              int64
# dtype: object

# %%
# lets convert remaing all dates as well into days

# %%
df['posting_date'] = df['posting_date'].sub(pd.to_datetime('1970-01-01'), axis=0)

# %%
df['posting_date']=df['posting_date'].dt.days

# %%
df['document_create_date'] = df['document_create_date'].sub(pd.to_datetime('1970-01-01'), axis=0)

# %%
df['document_create_date']=df['document_create_date'].dt.days

# %%
df['document_create_date.1'] = df['document_create_date.1'].sub(pd.to_datetime('1970-01-01'), axis=0)

# %%
df['document_create_date.1']=df['document_create_date.1'].dt.days

# %%
df['baseline_create_date'] = df['baseline_create_date'].sub(pd.to_datetime('1970-01-01'), axis=0)

# %%
df['baseline_create_date']=df['baseline_create_date'].dt.days

# %%
df.dtypes
# all dates column are now in int64 datatype
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year               int64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# delay                       int64
# dtype: object

# %%
df
# Out:
#       business_code cust_number       name_customer  clear_date  \
# 39428          U001  0200455322      PEA foundation       17946
# 19975          U001  0200519201    KROGE foundation       17910
# 41334          U001  0200769623     WAL-MAR systems       17905
# 18739          U001  0200769623  WAL-MAR associates       17905
# 6124           U001  0200726979          BJ'S  corp       17911
# ...             ...         ...                 ...         ...
# 34093          CA02  0140105847    GORDON F systems       18337
# 48621          CA02  0140105686            SYSC llc       18340
# 22219          CA02  0140104409             LOB llc       18337
# 48326          CA02  0140106293           ATLANT co       18337
# 45324          U001  0200424504               M  us       18337
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 39428           2019  1.928625e+09         17911                 17911
# ...

# %% [markdown]
# ### splitting into train , validation, and local test

# %%
# lets split the dataset into Training set , validation and local test
# split accordin to baseline_create_date like first 10 months use for validation , and next 2 months for validation and next 2 month for local test

# %%
# ERROR lets do other way 
df.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year               int64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# delay                       int64
# dtype: object

# %%
df['delay'].dtypes
# Out:
# dtype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39098 entries, 39428 to 45324
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           39098 non-null  object
#  1   cust_number             39098 non-null  object
#  2   name_customer           39098 non-null  object
#  3   clear_date              39098 non-null  int64
#  4   buisness_year           39098 non-null  int64
#  5   doc_id                  39098 non-null  float64
#  6   posting_date            39098 non-null  int64
#  7   document_create_date    39098 non-null  int64
#  8   document_create_date.1  39098 non-null  int64
#  9   due_in_date             39098 non-null  int64
#  10  invoice_currency        39098 non-null  object
#  11  document type           39098 non-null  object
#  12  total_open_amount       39098 non-null  float64
#  13  baseline_create_date    39098 non-null  int64
# ...

# %%
# lets do other way by using train_test_split function

# %%
x = df.drop('delay',axis=1)

# %%
y = df['delay']

# %%
#splitting first 70% as train and rest 30% as validation and Local test equally 
from sklearn.model_selection import train_test_split
x_train,x_inter_test,y_train,y_inter_test = train_test_split(x,y,test_size=0.3,random_state=0 , shuffle = False)

# %%
x_val,x_test,y_val,y_test = train_test_split(x_inter_test,y_inter_test,test_size=0.5,random_state=0 , shuffle = False)

# %%
x_train
# Out:
#       business_code cust_number       name_customer  clear_date  \
# 39428          U001  0200455322      PEA foundation       17946
# 19975          U001  0200519201    KROGE foundation       17910
# 41334          U001  0200769623     WAL-MAR systems       17905
# 18739          U001  0200769623  WAL-MAR associates       17905
# 6124           U001  0200726979          BJ'S  corp       17911
# ...             ...         ...                 ...         ...
# 18492          U001  0200974851            RESTA us       18193
# 34361          CA02  0140106271           LONGO  in       18192
# 48811          CA02  0140106408          WAL-M corp       18198
# 5387           U001  0200726979            BJ'S  in       18193
# 21614          U001  0200820380  SMITH'S foundation       18218
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 39428           2019  1.928625e+09         17911                 17911
# ...

# %%
x_val
# Out:
#       business_code cust_number        name_customer  clear_date  \
# 12103          U001  0200315290                 KWI        18193
# 17813          U001  0200769623      WAL-MAR systems       18190
# 7120           U001  0200865666       RESTAU systems       18193
# 34430          U001  0200769623         WAL-MAR corp       18191
# 42484          U001  0100031704  DELHAIZE foundation       18194
# ...             ...         ...                  ...         ...
# 27321          U001  0200726979             BJ'S  in       18256
# 9773           CA02  0140104225       SAVE-ON- trust       18246
# 20179          U001  0200769623          WAL-MAR llc       18257
# 25998          U001  0200744019     TARG corporation       18256
# 23821          U001  0200769623      WAL-MAR systems       18253
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 12103           2019  1.929963e+09         18178                 18173
# ...

# %%
x_test
# Out:
#       business_code cust_number       name_customer  clear_date  \
# 35002          U001  0200769623  WAL-MAR foundation       18253
# 11154          U001  0200793513      KROGER systems       18256
# 25848          U001  0200762301          C&S WH llc       18257
# 49042          U001  0200704045               RA us       18256
# 20019          U001  0200794332    COST corporation       18256
# ...             ...         ...                 ...         ...
# 34093          CA02  0140105847    GORDON F systems       18337
# 48621          CA02  0140105686            SYSC llc       18340
# 22219          CA02  0140104409             LOB llc       18337
# 48326          CA02  0140106293           ATLANT co       18337
# 45324          U001  0200424504               M  us       18337
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 35002           2019  1.930261e+09         18241                 18240
# ...

# %%
x_train.shape,x_val.shape,x_test.shape
# Out:
# ((27368, 16), (5865, 16), (5865, 16))

# %%
x_train.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year               int64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# dtype: object

# %%
pd.options.mode.chained_assignment = None

# %% [markdown]
# # EDA

# %%
# lets see covarience matrix of dataframe so we geta an of how columns are correlated
x_train.cov()
# Out:
#                           clear_date  buisness_year        doc_id  \
# clear_date              6.621330e+03            0.0  3.376708e+08
# buisness_year           0.000000e+00            0.0  0.000000e+00
# doc_id                  3.376708e+08            0.0  8.958283e+16
# posting_date            6.425032e+03            0.0  6.178315e+06
# document_create_date    6.424567e+03            0.0  7.961529e+07
# document_create_date.1  6.424908e+03            0.0 -4.032613e+07
# due_in_date             6.523577e+03            0.0 -3.595549e+08
# total_open_amount       1.289621e+04            0.0  2.044529e+12
# baseline_create_date    6.429327e+03            0.0  1.991915e+08
# invoice_id              2.497297e+08            0.0  7.729390e+16
#
#                         posting_date  document_create_date  \
# clear_date              6.425032e+03          6.424567e+03
# buisness_year           0.000000e+00          0.000000e+00
# doc_id                  6.178315e+06          7.961529e+07
# ...

# %%
cor_matrix = x_train.corr().abs()
cor_matrix
# Out:
#                         clear_date  buisness_year    doc_id  posting_date  \
# clear_date                1.000000            NaN  0.013865      0.983561
# buisness_year                  NaN            NaN       NaN           NaN
# doc_id                    0.013865            NaN  1.000000      0.000257
# posting_date              0.983561            NaN  0.000257      1.000000
# document_create_date      0.983165            NaN  0.003312      0.999818
# document_create_date.1    0.983476            NaN  0.001678      0.999981
# due_in_date               0.989400            NaN  0.014826      0.990207
# total_open_amount         0.004022            NaN  0.173372      0.014452
# baseline_create_date      0.983736            NaN  0.008286      0.999545
# invoice_id                0.011039            NaN  0.928890      0.003832
#
#                         document_create_date  document_create_date.1  \
# clear_date                          0.983165                0.983476
# ...

# %%
x_train['buisness_year'].dtypes
# Out:
# dtype('int64')

# %%
x_train.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year               int64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# dtype: object

# %%
x_train['invoice_id'].corr(x_train['doc_id'])*100
# Out:
# 92.8889888889204

# %%
x_train.nunique()
# Out:
# business_code                 6
# cust_number                1249
# name_customer              3327
# clear_date                  282
# buisness_year                 1
# doc_id                    27368
# posting_date                285
# document_create_date        287
# document_create_date.1      285
# due_in_date                 339
# invoice_currency              2
# document type                 2
# total_open_amount         25103
# baseline_create_date        285
# cust_payment_terms           64
# invoice_id                27363
# dtype: int64

# %%
#lets drop buisness_year column it is a constant value for training set so we can drop
x_train.drop(['buisness_year'],axis=1,inplace=True)

# %%
x_val['buisness_year'].var()
# Out:
# 0.0005113344940561811

# %%
x_val.drop(['buisness_year'],axis=1,inplace=True)

# %%
x_test.nunique()
# Out:
# business_code                5
# cust_number                541
# name_customer             1523
# clear_date                 117
# buisness_year                2
# doc_id                    5865
# posting_date                88
# document_create_date        89
# document_create_date.1      88
# due_in_date                140
# invoice_currency             2
# document type                1
# total_open_amount         5519
# baseline_create_date        83
# cust_payment_terms          49
# invoice_id                5865
# dtype: int64

# %%
x_test['buisness_year'].var()
# Out:
# 0.09802973683692133

# %%
x_test.drop(['buisness_year'],axis=1,inplace=True)

# %%
# lets see counts plots of baseline_create_date to get an idea of its distribution
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=8,8
sns.countplot(df['baseline_create_date'])

# %%
#lets plot scatterplot of columns too see the relation

# %%
sns.scatterplot(x=df['due_in_date'], y=df['total_open_amount'])

# %%
sns.countplot(x_train['business_code'])

# %%
sns.scatterplot(x=x_train['due_in_date'], y=y_train)

# %%
# well correlated and linear
sns.scatterplot(x=x_train['posting_date'], y=x_train['document_create_date'])

# %%
#linear and overlapped 
sns.scatterplot(x=x_train['posting_date'], y=x_train['document_create_date.1'])

# %%
x_train['posting_date'].corr(x_train['document_create_date.1'])*100
# Out:
# 99.99806497474

# %%
x_train['posting_date'].corr(x_train['document_create_date'])*100
# Out:
# 99.98178585421593

# %%
x_train['document_create_date'].corr(x_train['document_create_date.1'])*100
# Out:
# 99.97976981023808

# %%
sns.scatterplot(x=x_train['due_in_date'], y=x_train['total_open_amount'])

# %%
sns.jointplot(x=df['due_in_date'], y=df['document_create_date']);
# Out:
# C:\Users\mohit\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
x_train.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# dtype: object

# %%
# pair plot gives good idea of relations of two columns at a time 
cols = ['posting_date', 'document_create_date', 'document_create_date.1','due_in_date','clear_date','baseline_create_date', 'total_open_amount']
sns.pairplot(df[cols])

# %%
sns.countplot(df['cust_payment_terms'])

# %%
#lets see box plot of total_open_amount column ( tells if there are any outliers)
sns.boxplot(x=df['total_open_amount'])

# %% [markdown]
# # Feature Engineering

# %%
pd.options.mode.chained_assignment = None

# %%
# Currency conversion

# %%
pip install forex-python
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install forex-python
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
from forex_python.converter import CurrencyRates

# %%
c = CurrencyRates()

# %%
c.get_rate('CAD', 'USD')
# Out:
# 0.7837981761299341

# %%
c.get_rates('USD')
# Out:
# {'EUR': 0.8492569002123143,
#  'JPY': 109.57961783439491,
#  'BGN': 1.6609766454352441,
#  'CZK': 21.776645435244163,
#  'DKK': 6.316857749469214,
#  'GBP': 0.7349893842887474,
#  'HUF': 305.26539278131634,
#  'PLN': 3.9026751592356685,
#  'RON': 4.183014861995754,
#  'SEK': 8.707855626326964,
#  'CHF': 0.9204246284501062,
#  'ISK': 124.75583864118896,
#  'NOK': 9.016560509554141,
#  'HRK': 6.387261146496815,
#  'RUB': 74.46072186836518,
#  'TRY': 8.548959660297239,
#  'AUD': 1.3657749469214437,
#  'BRL': 5.234225053078556,
#  'CAD': 1.2758386411889597,
#  'CNY': 6.480254777070064,
#  'HKD': 7.773163481953292,
#  'IDR': 14559.244161358809,
#  'INR': 74.66751592356688,
#  'KRW': 1148.5265392781316,
#  'MXN': 20.041613588110405,
#  'MYR': 4.224458598726115,
#  'NZD': 1.4478980891719746,
#  'PHP': 50.95966029723992,
#  'SGD': 1.3678131634819533,
#  'THB': 32.81019108280255,
#  'ZAR': 14.551932059447982}

# %%
from forex_python.converter import CurrencyRates
c = CurrencyRates()

# %%
# forex python didnt work for me ;(
# working  other way by considering averaging exachange rate of cad to usd over a year

# %%
x_train
# Out:
#       business_code cust_number       name_customer  clear_date        doc_id  \
# 39428          U001  0200455322      PEA foundation       17946  1.928625e+09
# 19975          U001  0200519201    KROGE foundation       17910  1.928536e+09
# 41334          U001  0200769623     WAL-MAR systems       17905  1.928545e+09
# 18739          U001  0200769623  WAL-MAR associates       17905  1.928543e+09
# 6124           U001  0200726979          BJ'S  corp       17911  1.928540e+09
# ...             ...         ...                 ...         ...           ...
# 18492          U001  0200974851            RESTA us       18193  1.929989e+09
# 34361          CA02  0140106271           LONGO  in       18192  2.960584e+09
# 48811          CA02  0140106408          WAL-M corp       18198  2.960584e+09
# 5387           U001  0200726979            BJ'S  in       18193  1.929989e+09
# 21614          U001  0200820380  SMITH'S foundation       18218  1.929990e+09
#
# ...

# %%
# converting in same currencies ( Global_currency)
x_train["Global_currency"] = np.where(x_train["invoice_currency"].str.contains("CAD"),0.758, 1)

# %%
x_train
# Out:
#       business_code cust_number       name_customer  clear_date        doc_id  \
# 39428          U001  0200455322      PEA foundation       17946  1.928625e+09
# 19975          U001  0200519201    KROGE foundation       17910  1.928536e+09
# 41334          U001  0200769623     WAL-MAR systems       17905  1.928545e+09
# 18739          U001  0200769623  WAL-MAR associates       17905  1.928543e+09
# 6124           U001  0200726979          BJ'S  corp       17911  1.928540e+09
# ...             ...         ...                 ...         ...           ...
# 18492          U001  0200974851            RESTA us       18193  1.929989e+09
# 34361          CA02  0140106271           LONGO  in       18192  2.960584e+09
# 48811          CA02  0140106408          WAL-M corp       18198  2.960584e+09
# 5387           U001  0200726979            BJ'S  in       18193  1.929989e+09
# 21614          U001  0200820380  SMITH'S foundation       18218  1.929990e+09
#
# ...

# %%
x_train["total_open_amount"]=x_train['total_open_amount']*x_train['Global_currency']

# %%
x_train
# Out:
#       business_code cust_number       name_customer  clear_date        doc_id  \
# 39428          U001  0200455322      PEA foundation       17946  1.928625e+09
# 19975          U001  0200519201    KROGE foundation       17910  1.928536e+09
# 41334          U001  0200769623     WAL-MAR systems       17905  1.928545e+09
# 18739          U001  0200769623  WAL-MAR associates       17905  1.928543e+09
# 6124           U001  0200726979          BJ'S  corp       17911  1.928540e+09
# ...             ...         ...                 ...         ...           ...
# 18492          U001  0200974851            RESTA us       18193  1.929989e+09
# 34361          CA02  0140106271           LONGO  in       18192  2.960584e+09
# 48811          CA02  0140106408          WAL-M corp       18198  2.960584e+09
# 5387           U001  0200726979            BJ'S  in       18193  1.929989e+09
# 21614          U001  0200820380  SMITH'S foundation       18218  1.929990e+09
#
# ...

# %%
x_train.drop(['Global_currency'],axis=1,inplace=True)

# %%
x_train
# Out:
#       business_code cust_number       name_customer  clear_date        doc_id  \
# 39428          U001  0200455322      PEA foundation       17946  1.928625e+09
# 19975          U001  0200519201    KROGE foundation       17910  1.928536e+09
# 41334          U001  0200769623     WAL-MAR systems       17905  1.928545e+09
# 18739          U001  0200769623  WAL-MAR associates       17905  1.928543e+09
# 6124           U001  0200726979          BJ'S  corp       17911  1.928540e+09
# ...             ...         ...                 ...         ...           ...
# 18492          U001  0200974851            RESTA us       18193  1.929989e+09
# 34361          CA02  0140106271           LONGO  in       18192  2.960584e+09
# 48811          CA02  0140106408          WAL-M corp       18198  2.960584e+09
# 5387           U001  0200726979            BJ'S  in       18193  1.929989e+09
# 21614          U001  0200820380  SMITH'S foundation       18218  1.929990e+09
#
# ...

# %%
# do same for val and test dataset as well
x_val['Global_currency']=x_val.invoice_currency.map({'USD':1,'CAD':0.758})

# %%
x_val
# Out:
#       business_code cust_number        name_customer  clear_date  \
# 12103          U001  0200315290                 KWI        18193
# 17813          U001  0200769623      WAL-MAR systems       18190
# 7120           U001  0200865666       RESTAU systems       18193
# 34430          U001  0200769623         WAL-MAR corp       18191
# 42484          U001  0100031704  DELHAIZE foundation       18194
# ...             ...         ...                  ...         ...
# 27321          U001  0200726979             BJ'S  in       18256
# 9773           CA02  0140104225       SAVE-ON- trust       18246
# 20179          U001  0200769623          WAL-MAR llc       18257
# 25998          U001  0200744019     TARG corporation       18256
# 23821          U001  0200769623      WAL-MAR systems       18253
#
#              doc_id  posting_date  document_create_date  \
# 12103  1.929963e+09         18178                 18173
# 17813  1.929965e+09         18178                 18173
# ...

# %%
x_val["total_open_amount"]=x_val['total_open_amount']*x_val['Global_currency']

# %%
x_val.drop(['Global_currency'],axis=1,inplace=True)

# %%
x_test['Global_currency']=x_test.invoice_currency.map({'USD':1,'CAD':0.758})

# %%
x_test["total_open_amount"]=x_test['total_open_amount']*x_test['Global_currency']

# %%
x_test.drop(['Global_currency'],axis=1,inplace=True)

# %%
x_train.shape,x_val.shape,x_test.shape
# Out:
# ((27368, 15), (5865, 15), (5865, 15))

# %%
x_train.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# dtype: object

# %%
# drop the invoice currency column from all three datasets
x_train.drop(['invoice_currency'],axis=1,inplace=True)

# %%
x_val.drop(['invoice_currency'],axis=1,inplace=True)

# %%
x_test.drop(['invoice_currency'],axis=1,inplace=True)

# %%
x_train
# Out:
#       business_code cust_number       name_customer  clear_date        doc_id  \
# 39428          U001  0200455322      PEA foundation       17946  1.928625e+09
# 19975          U001  0200519201    KROGE foundation       17910  1.928536e+09
# 41334          U001  0200769623     WAL-MAR systems       17905  1.928545e+09
# 18739          U001  0200769623  WAL-MAR associates       17905  1.928543e+09
# 6124           U001  0200726979          BJ'S  corp       17911  1.928540e+09
# ...             ...         ...                 ...         ...           ...
# 18492          U001  0200974851            RESTA us       18193  1.929989e+09
# 34361          CA02  0140106271           LONGO  in       18192  2.960584e+09
# 48811          CA02  0140106408          WAL-M corp       18198  2.960584e+09
# 5387           U001  0200726979            BJ'S  in       18193  1.929989e+09
# 21614          U001  0200820380  SMITH'S foundation       18218  1.929990e+09
#
# ...

# %%
# working on total_open_amount column

# %%
sns.distplot(x_train['total_open_amount'])
# Out:
# C:\Users\mohit\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# working on outliers , lets see by plotting box plot

# %%
sns.boxplot(x=df['total_open_amount'])

# %%
#we see that the outliers are present

# %%
Q1 = x_train.quantile(0.25)
Q3 = x_train.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# clear_date                   139.0000
# doc_id                    771093.2500
# posting_date                 139.0000
# document_create_date         138.0000
# document_create_date.1       139.0000
# due_in_date                  137.0000
# total_open_amount          40687.2925
# baseline_create_date         138.0000
# invoice_id                771093.2500
# dtype: float64

# %%
Q1 = x_train['total_open_amount'].quantile(0.25)
Q3 = x_train['total_open_amount'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 40687.292499999996

# %%
print(x_train['total_open_amount'].skew())
# Out:
# 2.325086010486241

# %%
# lets make it normal distriibution or eliminate outliers 
x_train.total_open_amount.hist()

# %%
#positive skew

# %%
#log transformation
x_train["Log_amt"] = x_train["total_open_amount"].map(lambda i: np.log(i) if i > 0 else 0) 
print(x_train['total_open_amount'].skew())
print(x_train['Log_amt'].skew())
# Out:
# 2.325086010486241
# -0.9539903638652331

# %%
x_train.Log_amt.hist()

# %%
# after log transformation

# %%
sns.boxplot(x=x_train['Log_amt'])

# %%
#there seems to be outliers even after log transform.:(

# %%
# or other way replace with median and check the box plot

# %%
print(x_train['total_open_amount'].quantile(0.50)) 
print(x_train['total_open_amount'].quantile(0.95))
# Out:
# 16618.1
# 107667.41100000001

# %%
x_train['median_amt'] = np.where(x_train['total_open_amount'] > 108788.84199999999, 17028.88,x_train['total_open_amount'])

# %%
sns.boxplot(x=x_train['median_amt'])

# %%
# no outliers finally yay

# %%
x_train['total_open_amount']=x_train["median_amt"]

# %%
x_train.drop("Log_amt",axis=1,inplace=True)

# %%
x_train.drop("median_amt",axis=1,inplace=True)

# %%
x_train
# Out:
#       business_code cust_number       name_customer  clear_date        doc_id  \
# 39428          U001  0200455322      PEA foundation       17946  1.928625e+09
# 19975          U001  0200519201    KROGE foundation       17910  1.928536e+09
# 41334          U001  0200769623     WAL-MAR systems       17905  1.928545e+09
# 18739          U001  0200769623  WAL-MAR associates       17905  1.928543e+09
# 6124           U001  0200726979          BJ'S  corp       17911  1.928540e+09
# ...             ...         ...                 ...         ...           ...
# 18492          U001  0200974851            RESTA us       18193  1.929989e+09
# 34361          CA02  0140106271           LONGO  in       18192  2.960584e+09
# 48811          CA02  0140106408          WAL-M corp       18198  2.960584e+09
# 5387           U001  0200726979            BJ'S  in       18193  1.929989e+09
# 21614          U001  0200820380  SMITH'S foundation       18218  1.929990e+09
#
# ...

# %%
#skew is decreased 
print(x_train['total_open_amount'].skew())
# Out:
# 1.2741575787796429

# %%
# lets see distribution plot once
sns.distplot(x_train['total_open_amount'])
# Out:
# C:\Users\mohit\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
x_train.nunique()
# Out:
# business_code                 6
# cust_number                1249
# name_customer              3327
# clear_date                  282
# doc_id                    27368
# posting_date                285
# document_create_date        287
# document_create_date.1      285
# due_in_date                 339
# document type                 2
# total_open_amount         23816
# baseline_create_date        285
# cust_payment_terms           64
# invoice_id                27363
# dtype: int64

# %%
# encoding  document type ( custom encoding)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
x_train['document type'].value_counts()
# Out:
# RV    27362
# X2        6
# Name: document type, dtype: int64

# %%
x_train.nunique()
# Out:
# business_code                 6
# cust_number                1249
# name_customer              3327
# clear_date                  282
# doc_id                    27368
# posting_date                285
# document_create_date        287
# document_create_date.1      285
# due_in_date                 339
# document type                 2
# total_open_amount         23816
# baseline_create_date        285
# cust_payment_terms           64
# invoice_id                27363
# dtype: int64

# %%
x_train['business_code'].value_counts()
# Out:
# U001    24694
# CA02     2169
# U013      405
# U002       91
# U005        7
# U007        2
# Name: business_code, dtype: int64

# %%
business_encoder = LabelEncoder()
business_encoder.fit(x_train['business_code'])
x_train['buzz'] = business_encoder.transform(x_train['business_code'])

# %%
x_train[['business_code','buzz']].tail(100)
# Out:
#       business_code  buzz
# 22880          U001     1
# 24339          U001     1
# 15937          U001     1
# 22394          U001     1
# 16939          U001     1
# ...             ...   ...
# 18492          U001     1
# 34361          CA02     0
# 48811          CA02     0
# 5387           U001     1
# 21614          U001     1
#
# [100 rows x 2 columns]

# %%
x_train['business_code']=x_train['buzz']

# %%
x_train.drop(['buzz'],axis=1,inplace=True)

# %%
x_train
# Out:
#        business_code cust_number       name_customer  clear_date  \
# 39428              1  0200455322      PEA foundation       17946
# 19975              1  0200519201    KROGE foundation       17910
# 41334              1  0200769623     WAL-MAR systems       17905
# 18739              1  0200769623  WAL-MAR associates       17905
# 6124               1  0200726979          BJ'S  corp       17911
# ...              ...         ...                 ...         ...
# 18492              1  0200974851            RESTA us       18193
# 34361              0  0140106271           LONGO  in       18192
# 48811              0  0140106408          WAL-M corp       18198
# 5387               1  0200726979            BJ'S  in       18193
# 21614              1  0200820380  SMITH'S foundation       18218
#
#              doc_id  posting_date  document_create_date  \
# 39428  1.928625e+09         17911                 17911
# 19975  1.928536e+09         17895                 17894
# ...

# %%
x_train['business_code'].value_counts()
# skewed one
# So using encoder doesnt normalize the feature, better go for custom encoding
# Out:
# 1    24694
# 0     2169
# 5      405
# 2       91
# 3        7
# 4        2
# Name: business_code, dtype: int64

# %%
#custom encoding for buiness code column

# %%
x_train['business_code']  = x_train['business_code'].replace({'U001': 1, 'CA02': 2, 'U013':2,'U002':2,'U005':2,'U007':2})

# %%
x_val['business_code']  = x_val['business_code'].replace({'U001': 1, 'CA02': 2, 'U013':2,'U002':2,'U005':2,'U007':2})

# %%
x_test['business_code']  = x_test['business_code'].replace({'U001': 1, 'CA02': 2, 'U013':2,'U002':2,'U005':2,'U007':2})

# %%
x_test['business_code'].value_counts()
# Out:
# 1    5305
# 2     560
# Name: business_code, dtype: int64

# %%
# lets see for name_customer column its value counts
x_train['name_customer'].value_counts()
# Out:
# WAL-MAR          612
# WAL-MAR co       606
# WAL-MAR in       601
# WAL-MAR corp     600
# WAL-MAR us       592
#                 ...
# FOODST             1
# TOUC llc           1
# FLAHA corp         1
# CHENE trust        1
# H.J. HEI corp      1
# Name: name_customer, Length: 3327, dtype: int64

# %%
name_encoder = LabelEncoder()
name_encoder.fit(x_train['name_customer'])
x_train['name_customer'] = name_encoder.transform(x_train['name_customer'])

# %%
x_val['name_customer'] = name_encoder.fit_transform(x_val['name_customer'])
x_test['name_customer'] = name_encoder.fit_transform(x_test['name_customer'])

# %%
x_val
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 12103              1  0200315290            769       18193  1.929963e+09
# 17813              1  0200769623           1470       18190  1.929965e+09
# 7120               1  0200865666           1108       18193  1.929995e+09
# 34430              1  0200769623           1465       18191  1.929990e+09
# 42484              1  0100031704            359       18194  1.929990e+09
# ...              ...         ...            ...         ...           ...
# 27321              1  0200726979            155       18256  1.930255e+09
# 9773               2  0140104225           1155       18246  2.960596e+09
# 20179              1  0200769623           1469       18257  1.930262e+09
# 25998              1  0200744019           1361       18256  1.930255e+09
# 23821              1  0200769623           1470       18253  1.930256e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
x_train.nunique()
# Out:
# business_code                 6
# cust_number                1249
# name_customer              3327
# clear_date                  282
# doc_id                    27368
# posting_date                285
# document_create_date        287
# document_create_date.1      285
# due_in_date                 339
# document type                 2
# total_open_amount         23816
# baseline_create_date        285
# cust_payment_terms           64
# invoice_id                27363
# dtype: int64

# %%
# customer number - frequency encoding

# %%
x_train.groupby('cust_number').agg(lambda x: x.value_counts().index[0])
# Out:
#              business_code  name_customer  clear_date        doc_id  \
# cust_number
# 0100000048               1           1133       18172  1.929270e+09
# 0100000158               1            480       17988  1.929067e+09
# 0100000217               1           2120       17973  1.928678e+09
# 0100000222               1           2745       18057  1.929724e+09
# 0100000533               1            308       18150  1.929667e+09
# ...                    ...            ...         ...           ...
# CC7455                   5           1342       18230  1.991831e+09
# CCCA02                   1           1662       18019  1.929898e+09
# CCU001                   0           1667       18075  2.960550e+09
# CCU002                   1           1700       18047  1.929882e+09
# CCU013                   1           1676       18047  1.929319e+09
#
#              posting_date  document_create_date  document_create_date.1  \
# cust_number
# ...

# %%
#x_train.pivot_table(index='cust_number', columns='name_customer',values=x_train['name_customer'].value_counts(), aggfunc=np.sum, fill_value = 0)

# %%
from sunbird.categorical_encoding import frequency_encoding

# %%
freqs_encoder = frequency_encoding(x_train , 'cust_number')

# %%
# frequency encoding of cust_number
count_map = x_train['cust_number'].value_counts().to_dict()

# %%
x_train['frequency_customers']=x_train['cust_number'].apply(lambda x : count_map[x])

# %%
x_train['frequency_customers'].value_counts()
# Out:
# 5810    5810
# 1043    1043
# 789      789
# 699      699
# 631      631
#         ...
# 45        45
# 41        41
# 40        40
# 38        38
# 25        25
# Name: frequency_customers, Length: 118, dtype: int64

# %%
x_train
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 39428              1  0200455322           2282       17946  1.928625e+09
# 19975              1  0200519201           1721       17910  1.928536e+09
# 41334              1  0200769623           3229       17905  1.928545e+09
# 18739              1  0200769623           3222       17905  1.928543e+09
# 6124               1  0200726979            329       17911  1.928540e+09
# ...              ...         ...            ...         ...           ...
# 18492              1  0200974851           2512       18193  1.929989e+09
# 34361              0  0140106271           1833       18192  2.960584e+09
# 48811              0  0140106408           3213       18198  2.960584e+09
# 5387               1  0200726979            332       18193  1.929989e+09
# 21614              1  0200820380           2733       18218  1.929990e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
# for val and test dataset also do frequency encoding for cust_number column
count_map = x_val['cust_number'].value_counts().to_dict()
x_val['frequency_customers']=x_val['cust_number'].apply(lambda x : count_map[x])

# %%
count_map = x_test['cust_number'].value_counts().to_dict()
x_test['frequency_customers']=x_test['cust_number'].apply(lambda x : count_map[x])

# %%
x_test['frequency_customers'].value_counts()
# Out:
# 1381    1381
# 275      275
# 1        232
# 193      193
# 184      184
# 174      174
# 2        156
# 3        123
# 114      114
# 8        104
# 5        100
# 4        100
# 14        98
# 95        95
# 47        94
# 7         91
# 13        91
# 10        90
# 87        87
# 86        86
# 17        85
# 9         81
# 40        80
# 79        79
# 78        78
# 6         78
# 11        77
# 71        71
# 34        68
# 65        65
# 16        64
# 21        63
# 62        62
# 61        61
# 15        60
# 20        60
# 58        58
# 54        54
# 52        52
# 50        50
# 25        50
# 49        49
# 24        48
# 46        46
# 45        45
# 44        44
# 22        44
# 43        43
# 39        39
# 19        38
# 36        36
# 12        36
# 18        36
# 35        35
# 33        33
# 29        29
# Name: frequency_customers, dtype: int64

# %%
# Cust_payement_terms label encodingg
x_train['cust_payment_terms'].value_counts()
# Out:
# NAA8    10926
# NAH4     7117
# CA10     2094
# NAC6      876
# NAM4      742
#         ...
# NA24        1
# C129        1
# NATK        1
# NAUY        1
# NATM        1
# Name: cust_payment_terms, Length: 64, dtype: int64

# %%
payterms_encoder = LabelEncoder()
payterms_encoder.fit(x_train['cust_payment_terms'])
x_train['cust_payment_terms'] = payterms_encoder.transform(x_train['cust_payment_terms'])

# %%
#label encoding for val,test of cust_payement_terms
x_val['cust_payment_terms'] = payterms_encoder.fit_transform(x_val['cust_payment_terms'])
x_test['cust_payment_terms'] = payterms_encoder.fit_transform(x_test['cust_payment_terms'])

# %%
x_test
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 35002              1  0200769623           1471       18253  1.930261e+09
# 11154              1  0200793513            768       18256  1.930257e+09
# 25848              1  0200762301            207       18257  1.930257e+09
# 49042              1  0200704045           1078       18256  1.930256e+09
# 20019              1  0200794332            275       18256  1.930257e+09
# ...              ...         ...            ...         ...           ...
# 34093              2  0140105847            535       18337  2.960617e+09
# 48621              2  0140105686           1305       18340  2.960616e+09
# 22219              2  0140104409            796       18337  2.960616e+09
# 48326              2  0140106293             88       18337  2.960616e+09
# 45324              1  0200424504            805       18337  1.930526e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
x_train.dtypes
# Out:
# business_code               int32
# cust_number                object
# name_customer               int32
# clear_date                  int64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# document type              object
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms          int32
# invoice_id                float64
# frequency_customers         int64
# dtype: object

# %%
# inmort target encoder inbuilt function
import sklearn

import pandas as pd 
from category_encoders import TargetEncoder
Targetenc = TargetEncoder()

# %%
# group and encode name_customer with the target delay

# %%
# first we will make new column with all delay as positives and encode with that as target

# %%
x_train['temp_delay']=y_train+100

# %%
x_train
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 39428              1  0200455322           2282       17946  1.928625e+09
# 19975              1  0200519201           1721       17910  1.928536e+09
# 41334              1  0200769623           3229       17905  1.928545e+09
# 18739              1  0200769623           3222       17905  1.928543e+09
# 6124               1  0200726979            329       17911  1.928540e+09
# ...              ...         ...            ...         ...           ...
# 18492              1  0200974851           2512       18193  1.929989e+09
# 34361              0  0140106271           1833       18192  2.960584e+09
# 48811              0  0140106408           3213       18198  2.960584e+09
# 5387               1  0200726979            332       18193  1.929989e+09
# 21614              1  0200820380           2733       18218  1.929990e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
x_train[['cust_number','temp_delay']].groupby('cust_number').mean()
# Out:
#              temp_delay
# cust_number
# 0100000048   135.000000
# 0100000158    75.500000
# 0100000217    98.000000
# 0100000222    95.636364
# 0100000533   105.666667
# ...                 ...
# CC7455       108.000000
# CCCA02       110.484507
# CCU001       107.250000
# CCU002       108.181818
# CCU013       143.331646
#
# [1249 rows x 1 columns]

# %%
x_train
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 39428              1  0200455322           2282       17946  1.928625e+09
# 19975              1  0200519201           1721       17910  1.928536e+09
# 41334              1  0200769623           3229       17905  1.928545e+09
# 18739              1  0200769623           3222       17905  1.928543e+09
# 6124               1  0200726979            329       17911  1.928540e+09
# ...              ...         ...            ...         ...           ...
# 18492              1  0200974851           2512       18193  1.929989e+09
# 34361              0  0140106271           1833       18192  2.960584e+09
# 48811              0  0140106408           3213       18198  2.960584e+09
# 5387               1  0200726979            332       18193  1.929989e+09
# 21614              1  0200820380           2733       18218  1.929990e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
# group the name_customer column and encode with target column ( target encoding mean() method)
# basically its the mean of all the delays by same customer 
x_train['name_encoded']=x_train['name_customer'].map(x_train.groupby('name_customer')['temp_delay'].mean())

# %%
x_train
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 39428              1  0200455322           2282       17946  1.928625e+09
# 19975              1  0200519201           1721       17910  1.928536e+09
# 41334              1  0200769623           3229       17905  1.928545e+09
# 18739              1  0200769623           3222       17905  1.928543e+09
# 6124               1  0200726979            329       17911  1.928540e+09
# ...              ...         ...            ...         ...           ...
# 18492              1  0200974851           2512       18193  1.929989e+09
# 34361              0  0140106271           1833       18192  2.960584e+09
# 48811              0  0140106408           3213       18198  2.960584e+09
# 5387               1  0200726979            332       18193  1.929989e+09
# 21614              1  0200820380           2733       18218  1.929990e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
#do same for val and test set also

# %%
x_val['temp_delay']=y_val+100
x_test['temp_delay']=y_test+100

# %%
x_val['name_encoded']=x_val['name_customer'].map(x_val.groupby('name_customer')['temp_delay'].mean())

# %%
x_val
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 12103              1  0200315290            769       18193  1.929963e+09
# 17813              1  0200769623           1470       18190  1.929965e+09
# 7120               1  0200865666           1108       18193  1.929995e+09
# 34430              1  0200769623           1465       18191  1.929990e+09
# 42484              1  0100031704            359       18194  1.929990e+09
# ...              ...         ...            ...         ...           ...
# 27321              1  0200726979            155       18256  1.930255e+09
# 9773               2  0140104225           1155       18246  2.960596e+09
# 20179              1  0200769623           1469       18257  1.930262e+09
# 25998              1  0200744019           1361       18256  1.930255e+09
# 23821              1  0200769623           1470       18253  1.930256e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
x_test['name_encoded']=x_test['name_customer'].map(x_test.groupby('name_customer')['temp_delay'].mean())

# %%
x_test
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 35002              1  0200769623           1471       18253  1.930261e+09
# 11154              1  0200793513            768       18256  1.930257e+09
# 25848              1  0200762301            207       18257  1.930257e+09
# 49042              1  0200704045           1078       18256  1.930256e+09
# 20019              1  0200794332            275       18256  1.930257e+09
# ...              ...         ...            ...         ...           ...
# 34093              2  0140105847            535       18337  2.960617e+09
# 48621              2  0140105686           1305       18340  2.960616e+09
# 22219              2  0140104409            796       18337  2.960616e+09
# 48326              2  0140106293             88       18337  2.960616e+09
# 45324              1  0200424504            805       18337  1.930526e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
x_train.shape,x_val.shape,x_test.shape
# Out:
# ((27368, 17), (5865, 17), (5865, 17))

# %%
x_train
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 39428              1  0200455322           2282       17946  1.928625e+09
# 19975              1  0200519201           1721       17910  1.928536e+09
# 41334              1  0200769623           3229       17905  1.928545e+09
# 18739              1  0200769623           3222       17905  1.928543e+09
# 6124               1  0200726979            329       17911  1.928540e+09
# ...              ...         ...            ...         ...           ...
# 18492              1  0200974851           2512       18193  1.929989e+09
# 34361              0  0140106271           1833       18192  2.960584e+09
# 48811              0  0140106408           3213       18198  2.960584e+09
# 5387               1  0200726979            332       18193  1.929989e+09
# 21614              1  0200820380           2733       18218  1.929990e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %% [markdown]
# #  Feature selection

# %%
#lets drop name_customer columns since we grouped and target encoded already

# %%
#x_val.drop(['name_customer'],axis=1,inplace=True)
#x_test.drop(['name_customer'],axis=1,inplace=True)

# %%
x_train
# Out:
#        business_code cust_number  name_customer  clear_date        doc_id  \
# 39428              1  0200455322           2282       17946  1.928625e+09
# 19975              1  0200519201           1721       17910  1.928536e+09
# 41334              1  0200769623           3229       17905  1.928545e+09
# 18739              1  0200769623           3222       17905  1.928543e+09
# 6124               1  0200726979            329       17911  1.928540e+09
# ...              ...         ...            ...         ...           ...
# 18492              1  0200974851           2512       18193  1.929989e+09
# 34361              0  0140106271           1833       18192  2.960584e+09
# 48811              0  0140106408           3213       18198  2.960584e+09
# 5387               1  0200726979            332       18193  1.929989e+09
# 21614              1  0200820380           2733       18218  1.929990e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# ...

# %%
x_train['posting_date'].corr(x_train['document_create_date'])*100
# Out:
# 99.98178585421593

# %%
x_train['document_create_date.1'].corr(x_train['document_create_date'])*100
# Out:
# 99.97976981023808

# %%
x_train['document_create_date.1'].corr(y_train)*100
# Out:
# -1.782454210454507

# %%
sns.scatterplot(x=x_train['posting_date'], y=y_train)

# %%
hm=x_train.corr()
f,ax=plt.subplots(figsize=(8,8))
sns.heatmap(hm,square=True)

# %%
# lets drop cust_number it has no effect in training the model .we already encoded it with frequency of customers
x_train.drop(['cust_number'],axis=1,inplace=True)
x_val.drop(['cust_number'],axis=1,inplace=True)
x_test.drop(['cust_number'],axis=1,inplace=True)

# %%
sns.scatterplot(x=x_train['name_encoded'], y=x_train['temp_delay'])

# %%
sns.scatterplot(x=x_train['frequency_customers'], y=y_train)

# %%
x_train['baseline_create_date'].corr(x_train['document_create_date'])*100
# Out:
# 99.93566311521161

# %%
cols = ['posting_date', 'document_create_date', 'document_create_date.1','due_in_date','clear_date','baseline_create_date','total_open_amount']
sns.pairplot(x_train[cols])

# %%
plt.rcParams["figure.figsize"]=10,10

# %%
# ploting heat map it gives good visualisation of what clumns needs to be selected
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(x_train.merge(y_train , on = x_train.index ).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
x_train['document type'].value_counts()
# Out:
# RV    27362
# X2        6
# Name: document type, dtype: int64

# %%
x_train.drop(['document type'],axis=1,inplace=True)
x_val.drop(['document type'],axis=1,inplace=True)
x_test.drop(['document type'],axis=1,inplace=True)

# %%
x_train.nunique()
# Out:
# business_code                 6
# name_customer              3327
# clear_date                  282
# doc_id                    27368
# posting_date                285
# document_create_date        287
# document_create_date.1      285
# due_in_date                 339
# total_open_amount         23816
# baseline_create_date        285
# cust_payment_terms           64
# invoice_id                27363
# frequency_customers         118
# temp_delay                  180
# name_encoded                735
# dtype: int64

# %%
sns.scatterplot(x=x_train['document_create_date'], y=x_train['document_create_date.1'])

# %%
x_train.drop(['document_create_date.1'],axis=1,inplace=True)
x_val.drop(['document_create_date.1'],axis=1,inplace=True)
x_test.drop(['document_create_date.1'],axis=1,inplace=True)

# %%
# more correlation between invoice and doc id

# %%
x_train['invoice_id'].corr(x_train['doc_id'])*100
# Out:
# 92.8889888889204

# %%
x_train['invoice_id'].corr(y_train)*100
# Out:
# 14.322216522626762

# %%
# lets dropp invoice id it has poor coreelation with target column and more correlation with doc_id
# we will keep doc_id

# %%
x_train.drop(['invoice_id'],axis=1,inplace=True)
x_val.drop(['invoice_id'],axis=1,inplace=True)
x_test.drop(['invoice_id'],axis=1,inplace=True)

# %%
x_train.dtypes
# Out:
# business_code             int32
# name_customer             int32
# clear_date                int64
# doc_id                  float64
# posting_date              int64
# document_create_date      int64
# due_in_date               int64
# total_open_amount       float64
# baseline_create_date      int64
# cust_payment_terms        int32
# frequency_customers       int64
# temp_delay                int64
# name_encoded            float64
# dtype: object

# %%
sns.scatterplot(x=x_train['due_in_date'], y=y_train)

# %%
sns.jointplot(x=x_train['document_create_date'], y=x_train['posting_date'])
# Out:
# C:\Users\mohit\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# high correlation 
x_train.drop(['posting_date'],axis=1,inplace=True)
x_val.drop(['posting_date'],axis=1,inplace=True)
x_test.drop(['posting_date'],axis=1,inplace=True)

# %%
hm=x_train.corr()
f,ax=plt.subplots(figsize=(8,8))
sns.heatmap(hm,square=True)

# %%
x_train.drop(['document_create_date'],axis=1,inplace=True)
x_val.drop(['document_create_date'],axis=1,inplace=True)
x_test.drop(['document_create_date'],axis=1,inplace=True)

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(x_train.merge(y_train , on = x_train.index ).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
x_train.drop(['temp_delay'],axis=1,inplace=True)
x_val.drop(['temp_delay'],axis=1,inplace=True)
x_test.drop(['temp_delay'],axis=1,inplace=True)

# %%
x_train.dtypes
# Out:
# business_code             int32
# name_customer             int32
# clear_date                int64
# doc_id                  float64
# due_in_date               int64
# total_open_amount       float64
# baseline_create_date      int64
# cust_payment_terms        int32
# frequency_customers       int64
# name_encoded            float64
# dtype: object

# %%
x_train.drop(['name_encoded'],axis=1,inplace=True)
x_val.drop(['name_encoded'],axis=1,inplace=True)
x_test.drop(['name_encoded'],axis=1,inplace=True)

# %%
x_train.shape,x_val.shape,x_test.shape
# Out:
# ((27368, 9), (5865, 9), (5865, 9))

# %% [markdown]
# ## standardization , normalization of datasets

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_test=sc.transform(x_test)
x_val=sc.transform(x_val)

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(0.8)
sel.fit(x_train)
# Out:
# VarianceThreshold(threshold=0.8)

# %% [markdown]
# ## create a base model

# %%
# linear regression doesnt fit here porperly due to non-linearity of few features .

# %% [markdown]
# ## decision tree regression

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0 , max_depth=15)

# %%
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=15, random_state=0)

# %%
y_predict2 = regressor.predict(x_val)

# %%
mean_squared_error(y_test, y_predict2, squared=False)
# Out:
# 14.413561687008961

# %%
import math

# %%
#MSE
print(mean_squared_error(y_test, y_predict2))
# Out:
# 207.75076050521264

# %%
# RMSE
print(math.sqrt(mean_squared_error(y_test, y_predict2)))
# Out:
# 14.413561687008961

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test, y_predict2))
# Out:
# 9.161530718051083

# %%
accuracy1=round(regressor.score(x_train, y_train)*100,2)

# %%
accuracy1
# Out:
# 86.29

# %%
y_val, y_predict2
# Out:
# (12103    0
#  17813   -3
#  7120     0
#  34430   -2
#  42484    1
#          ..
#  27321    0
#  9773    -5
#  20179    1
#  25998    0
#  23821   -3
#  Name: delay, Length: 5865, dtype: int64,
#  array([-5.60509554,  0.2597493 , -5.60509554, ...,  4.        ,
#          4.        ,  4.        ]))

# %% [markdown]
# ## Random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from pylab import rcParams
from sklearn import preprocessing
from sklearn import metrics 
from sklearn.metrics import classification_report

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 20, random_state = 0)
# Train the model on training data
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=20, random_state=0)

# %%
# random forest makes the model stable because it runs different number of decision trees parallely but since we have limited features we can go for decision tree model

# %%
# Predicting using Decision tree model.

# %% [markdown]
# ## Global_test final prediction

# %%
#preprocessing on global_test dataset
#feature engineering
#feauture selection
#predicting

# %%
global_test
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 1              U001   200769623  WAL-MAR foundation        NaN         2020.0
# 7              U001  0100036292              AMY co        NaN         2020.0
# 10             U001  0200778870        C associates        NaN         2020.0
# 11             U001  0200704858        WAKE systems        NaN         2020.0
# 15             U001  0200762301         C&S WH corp        NaN         2020.0
# ...             ...         ...                 ...        ...            ...
# 49967          U001  0200707741    SMART &  systems        NaN         2020.0
# 49978          U001  0200799342            MITCH in        NaN         2020.0
# 49979          U001  0200762301             C&S WH         NaN         2020.0
# 49981          U001   200726979         BJ'S  trust        NaN         2020.0
# 49994          U001   200418007      AM corporation        NaN         2020.0
#
# ...

# %%
global_test.drop(['area_business'],axis=1,inplace=True)

# %%
global_test['baseline_create_date']=pd.to_datetime(global_test['baseline_create_date'],format='%Y%m%d')

# %%
global_test['due_in_date']=pd.to_datetime(global_test['due_in_date'],format='%Y%m%d')

# %%
global_test.nunique()
# Out:
# business_code                5
# cust_number                663
# name_customer             1780
# clear_date                   0
# buisness_year                1
# doc_id                    9703
# posting_date                82
# document_create_date        89
# document_create_date.1      82
# due_in_date                126
# invoice_currency             2
# document type                1
# posting_id                   1
# total_open_amount         9004
# baseline_create_date        85
# cust_payment_terms          41
# invoice_id                9703
# isOpen                       1
# dtype: int64

# %%
global_test.drop(['invoice_id'],axis=1,inplace=True)

# %%
global_test.drop(['document_create_date'],axis=1,inplace=True)

# %%
global_test.drop(['document_create_date.1'],axis=1,inplace=True)

# %%
global_test['business_code'].value_counts()
# Out:
# U001    9198
# CA02     708
# U013      66
# U002      25
# U005       3
# Name: business_code, dtype: int64

# %%
global_test["Global_currency"] = np.where(global_test["invoice_currency"].str.contains("CAD"),0.758, 1)
global_test["total_open_amount"]=global_test['total_open_amount']*global_test['Global_currency']
global_test.drop(['Global_currency'],axis=1,inplace=True)

# %%
global_test['business_code']  = global_test['business_code'].replace({'U001': 1, 'CA02': 2, 'U013':2,'U002':2,'U005':2,'U007':2})

# %%
count_map =global_test['cust_number'].value_counts().to_dict()
global_test['frequency_customers']=global_test['cust_number'].apply(lambda x : count_map[x])

# %%
global_test['cust_payment_terms'] = payterms_encoder.fit_transform(global_test['cust_payment_terms'])

# %%
global_test.drop(['cust_number'],axis=1,inplace=True)

# %%
global_test['name_customer'] = name_encoder.fit_transform(global_test['name_customer'])

# %%
global_test
# Out:
#        business_code  name_customer clear_date  buisness_year        doc_id  \
# 1                  1           1721        NaN         2020.0  1.930766e+09
# 7                  1             84        NaN         2020.0  1.930769e+09
# 10                 1            260        NaN         2020.0  1.930587e+09
# 11                 1           1695        NaN         2020.0  1.930571e+09
# 15                 1            290        NaN         2020.0  1.930731e+09
# ...              ...            ...        ...            ...           ...
# 49967              1           1410        NaN         2020.0  1.930661e+09
# 49978              1           1083        NaN         2020.0  1.930841e+09
# 49979              1            287        NaN         2020.0  1.930769e+09
# 49981              1            206        NaN         2020.0  1.930714e+09
# 49994              1             65        NaN         2020.0  1.930858e+09
#
# ...

# %%
global_test.drop(['isOpen'],axis=1,inplace=True)

# %%
global_test.drop(['document type'],axis=1,inplace=True)

# %%
global_test.drop(['invoice_currency'],axis=1,inplace=True)

# %%
global_test
# Out:
#        business_code  name_customer clear_date  buisness_year        doc_id  \
# 1                  1           1721        NaN         2020.0  1.930766e+09
# 7                  1             84        NaN         2020.0  1.930769e+09
# 10                 1            260        NaN         2020.0  1.930587e+09
# 11                 1           1695        NaN         2020.0  1.930571e+09
# 15                 1            290        NaN         2020.0  1.930731e+09
# ...              ...            ...        ...            ...           ...
# 49967              1           1410        NaN         2020.0  1.930661e+09
# 49978              1           1083        NaN         2020.0  1.930841e+09
# 49979              1            287        NaN         2020.0  1.930769e+09
# 49981              1            206        NaN         2020.0  1.930714e+09
# 49994              1             65        NaN         2020.0  1.930858e+09
#
# ...

# %%
global_test.drop(['posting_date'],axis=1,inplace=True)

# %%
#global_test.drop(['buisness_year'],axis=1,inplace=True)

# %%
global_test.nunique()
# Out:
# business_code              2
# name_customer           1780
# clear_date                 0
# buisness_year              1
# doc_id                  9703
# due_in_date              126
# posting_id                 1
# total_open_amount       9004
# baseline_create_date      85
# cust_payment_terms        41
# frequency_customers       68
# dtype: int64

# %%
global_test.drop(['posting_id'],axis=1,inplace=True)

# %%
global_test['due_in_date'] = global_test['due_in_date'].sub(pd.to_datetime('1970-01-01'), axis=0)
global_test['due_in_date']=global_test['due_in_date'].dt.days

# %%
global_test['baseline_create_date'] = global_test['baseline_create_date'].sub(pd.to_datetime('1970-01-01'), axis=0)
global_test['baseline_create_date']=global_test['baseline_create_date'].dt.days

# %%
global_test.drop(['clear_date'],axis=1,inplace=True)

# %%
global_test.shape
# Out:
# (10000, 9)

# %%
global_test=sc.transform(global_test)

# %%
#random forest regression
final_result = regressor.predict(global_test)

# %%
final_result
# Out:
# array([-22.        ,   1.        ,  -5.60509554, ...,   6.        ,
#         -5.60509554,  -7.        ])

# %%
final_result = pd.Series(final_result,name='predicted_delay')

# %%
# predictions of delay
final_result
# Out:
# 0      -22.000000
# 1        1.000000
# 2       -5.605096
# 3       -5.605096
# 4        6.000000
#           ...
# 9995     3.625000
# 9996    -5.605096
# 9997     6.000000
# 9998    -5.605096
# 9999    -7.000000
# Name: predicted_delay, Length: 10000, dtype: float64

# %%
test.reset_index(drop=True,inplace=True)

# %%
Final = test.merge(final_result , on = test.index )
Final
# Out:
#       key_0 business_code cust_number       name_customer clear_date  \
# 0         0          U001   200769623  WAL-MAR foundation        NaN
# 1         1          U001  0100036292              AMY co        NaN
# 2         2          U001  0200778870        C associates        NaN
# 3         3          U001  0200704858        WAKE systems        NaN
# 4         4          U001  0200762301         C&S WH corp        NaN
# ...     ...           ...         ...                 ...        ...
# 9995   9995          U001  0200707741    SMART &  systems        NaN
# 9996   9996          U001  0200799342            MITCH in        NaN
# 9997   9997          U001  0200762301             C&S WH         NaN
# 9998   9998          U001   200726979         BJ'S  trust        NaN
# 9999   9999          U001   200418007      AM corporation        NaN
#
#       buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
Final['predicted_delay']=pd.to_timedelta(Final['predicted_delay'])

# %%
final_table=pd.read_csv("global_testfinal.csv")

# %%
pd.set_option('display.max_columns',None)

# %%
final_table
# Out:
#       Unnamed: 0 business_code cust_number       name_customer  clear_date  \
# 0              1          U001   200769623  WAL-MAR foundation         NaN
# 1              7          U001  0100036292              AMY co         NaN
# 2             10          U001  0200778870        C associates         NaN
# 3             11          U001  0200704858        WAKE systems         NaN
# 4             15          U001  0200762301         C&S WH corp         NaN
# ...          ...           ...         ...                 ...         ...
# 9995       49967          U001  0200707741    SMART &  systems         NaN
# 9996       49978          U001  0200799342            MITCH in         NaN
# 9997       49979          U001  0200762301             C&S WH          NaN
# 9998       49981          U001   200726979         BJ'S  trust         NaN
# 9999       49994          U001   200418007      AM corporation         NaN
#
# ...

# %%
final_table=final_table.merge( Final['predicted_delay'], on = test.index )

# %%
final_table['due_in_date']=pd.to_datetime(final_table['due_in_date'],format="%Y%m%d")

# %%
final_table['due_in_date']
# Out:
# 0      2020-04-24
# 1      2020-04-25
# 2      2020-03-18
# 3      2020-03-13
# 4      2020-04-18
#           ...
# 9995   2020-04-01
# 9996   2020-05-14
# 9997   2020-04-24
# 9998   2020-04-14
# 9999   2020-05-20
# Name: due_in_date, Length: 10000, dtype: datetime64[ns]

# %%
final_table['predicted_clear_date']=final_table['due_in_date'].add(final_table['predicted_delay'], axis=0)

# %%
final_table['predicted_clear_date']
final_table.drop(['predicted_delay'],axis=1,inplace=True)

# %%
final_table
# Out:
#       key_0  Unnamed: 0 business_code cust_number       name_customer  \
# 0         0           1          U001   200769623  WAL-MAR foundation
# 1         1           7          U001  0100036292              AMY co
# 2         2          10          U001  0200778870        C associates
# 3         3          11          U001  0200704858        WAKE systems
# 4         4          15          U001  0200762301         C&S WH corp
# ...     ...         ...           ...         ...                 ...
# 9995   9995       49967          U001  0200707741    SMART &  systems
# 9996   9996       49978          U001  0200799342            MITCH in
# 9997   9997       49979          U001  0200762301             C&S WH
# 9998   9998       49981          U001   200726979         BJ'S  trust
# 9999   9999       49994          U001   200418007      AM corporation
#
#       clear_date  buisness_year        doc_id posting_date  \
# 0            NaN         2020.0  1.930766e+09   2020-04-09
# ...
